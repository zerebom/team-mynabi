# %%
### 単位面積あたりの賃料を予測する

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
from scipy.stats import norm, skew
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import datetime
import seaborn as sns
sns.set()
import matplotlib

pd.set_option('max_columns',1000)
pd.set_option('max_rows',1000)


import warnings
warnings.filterwarnings('ignore')

import re
import geocoder
from geopy.distance import great_circle, vincenty
from tqdm import tqdm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import os
import gc
import lightgbm as lgb
from sklearn.model_selection import KFold, train_test_split
from time import time
import datetime
from script import RegressionPredictor,LogRegressionPredictor
import japanize_matplotlib
from utils import save_data
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
SEED=1234
n_splits=10

# %%
train=pd.read_csv('./input/prep_train1106.csv')
test=pd.read_csv('./input/prep_test1106.csv')
y_train = train['賃料']

# %%
drop_col = ['id']

## 必要な特徴量に絞る
y_train = train['賃料']
y_train_log = np.log1p(y_train)
X_train = train.drop(drop_col,axis=1)
X_test = test.drop(drop_col,axis=1)

# %%
def feature_encoding(train, test, category_col, target_col, func_list):
    '''target_encodingを重要な列（面積など）でやる。TEと違って、test_dfに含まれる値も集計して作る'''
    data=pd.concat([train,test],axis=0).reset_index()
    
    agg_func = {target_col: func_list}
    #agg_funcでgruopby
    agg_df = data.groupby(category_col)[target_col].agg(agg_func)
    #列名作成
    agg_df.columns = [category_col + '_' + '_'.join(col).strip() for col in agg_df.columns.values]
    #元の列に集約結果をmapしその値をコピーし新規列に加え返す。
    for col in agg_df.columns.values:
        train[col] = train[category_col].map(agg_df[col]).copy()
        test[col] = test[category_col].map(agg_df[col]).copy()
    return train, test

def target_encoding(train, test, category_col, target_col, func_list):
    '''target_encodingをやる。func_listに辞書型で列と処理する関数(meanとか)を渡す'''
    
    agg_func = {target_col: func_list}
    #agg_funcでgruopby
    agg_df = train.groupby(category_col)[target_col].agg(agg_func)
    #列名作成
    agg_df.columns = [category_col + '_' + '_'.join(col).strip() for col in agg_df.columns.values]
    #元の列に集約結果をmapしその値をコピーし新規列に加え返す。
    for col in agg_df.columns.values:
        train[col] = train[category_col].map(agg_df[col]).copy()
        test[col] = test[category_col].map(agg_df[col]).copy()
    return train, test

# %%
category_col='km_type_with_age'
X_train['地価'] = X_train['賃料'] / X_train['面積']
target_dict = {category_col: ['mean']}

for category_col, func_list in target_dict.items():
    X_train, X_test = feature_encoding(X_train, X_test, category_col, '地価', func_list)
    X_train, X_test = feature_encoding(X_train, X_test, category_col, '面積', func_list)
    X_train, X_test = feature_encoding(X_train, X_test, category_col, '築年数', func_list)

X_train['地価x面積'] = X_train['面積'] * X_train[f'{category_col}_地価_mean']
X_test['地価x面積'] = X_test['面積'] * X_test[f'{category_col}_地価_mean']

X_train['area_diff'] = X_train['面積'] - X_train[f'{category_col}_面積_mean']
X_train['area_ratio'] = X_train['面積'] / X_train[f'{category_col}_面積_mean']
X_test['area_diff'] = X_test['面積'] - X_test[f'{category_col}_面積_mean']
X_test['area_ratio'] = X_test['面積'] / X_test[f'{category_col}_面積_mean']

X_train['age_diff'] = X_train['築年数'] - X_train[f'{category_col}_築年数_mean']
X_train['age_ratio'] = X_train['築年数'] / X_train[f'{category_col}_築年数_mean']
X_test['age_diff'] = X_test['築年数'] - X_test[f'{category_col}_築年数_mean']
X_test['age_ratio'] = X_test['築年数'] / X_test[f'{category_col}_築年数_mean']

X_train['area/ageratio'] = X_train['area_ratio'] / X_train['age_ratio']
X_test['area/ageratio'] = X_test['area_ratio'] / X_test['age_ratio']

X_train['地価x面積'] = X_train['面積'] * X_train[f'{category_col}_地価_mean']
X_test['地価x面積'] = X_test['面積'] * X_test[f'{category_col}_地価_mean']
X_train['地価x面積/築年数ratio'] = X_train['地価x面積'] / X_train['age_ratio']
X_test['地価x面積/築年数ratio'] = X_test['地価x面積'] / X_test['age_ratio']

# %%
lgbm_params = {
    'num_iterations': 50000,
    'learning_rate': 0.01,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'reg_lambda': 68.19849585036235,
    'reg_alpha': 0.007585940082730346,
    'colsample_bytree': 0.6,
    'subsample': 0.5,
    'max_depth': 8,
    'min_child_weight': 8,
    'lambda': 1,
    'eta': 0.1,
    'verbose': 1,
    'random_state': 0,
    'early_stopping_round': 50
    }

lgbm_log_params=lgbm_params.copy()
lgbm_log_params['metric']='mae'
lgbm_log_params['learning_rate']=0.08

lgbm_x_params=lgbm_params.copy()
lgbm_x_params['metric']='cross_entropy'
lgbm_x_params['learning_rate']=0.08

# %%
folder=KFold(n_splits=10, shuffle=True, random_state=421)

# %%
features =  ['面積','築年数','sta_min','center_dis','L','loc_lat','loc_lon','総階数','畳','所在階','km_type_with_age_地価_mean', '地価x面積', 'area_diff',
       'area_ratio', 'age_diff', 'age_ratio',
       'area/ageratio', '地価x面積/築年数ratio']
X_train = X_train[features]
X_test = X_test[features]

# %%
train[]
# Out:
# Index(['id', '契約期間', '建物構造', '所在階', '方角', '築年数', '賃料', '間取り', '面積', '駐車場',
#        ...
#        '2012平均単価_mean', '2012平均単価_max', '2012平均単価_min', '2017平均単価_mean',
#        '2017平均単価_max', '2017平均単価_min', '上昇率_mean', '上昇率_max', '上昇率_min',
#        'km_type_with_age'],
#       dtype='object', length=212)

# %%
LogLGBM = LogRegressionPredictor(X_train, y_train.values, X_test, Folder=folder, params=lgbm_log_params,
                                      sk_model=None, n_splits=10, clf_type='lgb')
log_lgboof, log_lgbpreds, log_lgbFIs = LogLGBM.fit()
LogLGBM.plot_FI(50)
LogLGBM.plot_pred_dist()
LogLGBM.plot_scatter_oofvspred()
# Out:
# Training on fold 1
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0123303	valid_1's l1: 0.0524958
# [10000]	training's l1: 0.00510689	valid_1's l1: 0.0507163
# Early stopping, best iteration is:
# [11216]	training's l1: 0.00433561	valid_1's l1: 0.0505282
# Training on fold 2
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.012462	valid_1's l1: 0.0500421
# [10000]	training's l1: 0.00513429	valid_1's l1: 0.0482353
# Early stopping, best iteration is:
# [13617]	training's l1: 0.00326893	valid_1's l1: 0.0478066
# Training on fold 3
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0123604	valid_1's l1: 0.0518493
# [10000]	training's l1: 0.0051085	valid_1's l1: 0.0497784
# [15000]	training's l1: 0.00288106	valid_1's l1: 0.0491361
# [20000]	training's l1: 0.00193719	valid_1's l1: 0.0488641
# Early stopping, best iteration is:
# [24083]	training's l1: 0.00153537	valid_1's l1: 0.0487372
# Training on fold 4
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0124174	valid_1's l1: 0.0514897
# [10000]	training's l1: 0.0051321	valid_1's l1: 0.0496047
# [15000]	training's l1: 0.00282421	valid_1's l1: 0.0490071
# Early stopping, best iteration is:
# [17889]	training's l1: 0.00218721	valid_1's l1: 0.0488527
# Training on fold 5
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0124076	valid_1's l1: 0.0481179
# [10000]	training's l1: 0.00515295	valid_1's l1: 0.0463839
# Early stopping, best iteration is:
# [12835]	training's l1: 0.00361419	valid_1's l1: 0.0460291
# Training on fold 6
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0125518	valid_1's l1: 0.0495036
# Early stopping, best iteration is:
# [9558]	training's l1: 0.00554627	valid_1's l1: 0.0476491
# Training on fold 7
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0123785	valid_1's l1: 0.053728
# [10000]	training's l1: 0.00508877	valid_1's l1: 0.05157
# Early stopping, best iteration is:
# [14497]	training's l1: 0.00301198	valid_1's l1: 0.0510079
# Training on fold 8
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0122354	valid_1's l1: 0.0515712
# [10000]	training's l1: 0.0050465	valid_1's l1: 0.0496136
# [15000]	training's l1: 0.00279201	valid_1's l1: 0.0490043
# [20000]	training's l1: 0.00186726	valid_1's l1: 0.0487441
# Early stopping, best iteration is:
# [20676]	training's l1: 0.00178781	valid_1's l1: 0.0487225
# Training on fold 9
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0124057	valid_1's l1: 0.0507398
# [10000]	training's l1: 0.00516014	valid_1's l1: 0.0489696
# Early stopping, best iteration is:
# [13329]	training's l1: 0.00341192	valid_1's l1: 0.0485355
# Training on fold 10
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0123204	valid_1's l1: 0.0525006
# [10000]	training's l1: 0.00507246	valid_1's l1: 0.0506088
# Early stopping, best iteration is:
# [12126]	training's l1: 0.00384672	valid_1's l1: 0.0503054
# ------------------------------
# Training has finished.
# Total training time is 0:02:58.339535
# ------------------------------
# this self.model`s rmse: 14976
# RMSE :  14976.758317303678
# R^2 :  0.9551958653004351

# %%
int(np.sqrt(mean_squared_error(log_lgboof2, y_train)))
# Out:
# 15228

# %%
LogLGBM = LogRegressionPredictor(X_train, (y_train/X_train['面積']).values, X_test, Folder=folder, params=lgbm_log_params,
                                      sk_model=None, n_splits=10, clf_type='lgb')
log_lgboof, log_lgbpreds, log_lgbFIs = LogLGBM.fit()
LogLGBM.plot_FI(50)
LogLGBM.plot_pred_dist()
LogLGBM.plot_scatter_oofvspred()
# Out:
# Training on fold 1
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0194797	valid_1's l1: 0.0547037
# [10000]	training's l1: 0.00935162	valid_1's l1: 0.0517055
# [15000]	training's l1: 0.00549967	valid_1's l1: 0.0506911
# Early stopping, best iteration is:
# [19349]	training's l1: 0.00382667	valid_1's l1: 0.0503008
# Training on fold 2
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0196334	valid_1's l1: 0.0527052
# [10000]	training's l1: 0.00937185	valid_1's l1: 0.0500961
# Early stopping, best iteration is:
# [10976]	training's l1: 0.00833666	valid_1's l1: 0.0498052
# Training on fold 3
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0194643	valid_1's l1: 0.0540312
# [10000]	training's l1: 0.00940862	valid_1's l1: 0.0509482
# Early stopping, best iteration is:
# [14420]	training's l1: 0.00585887	valid_1's l1: 0.0499478
# Training on fold 4
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0196536	valid_1's l1: 0.052055
# [10000]	training's l1: 0.00950189	valid_1's l1: 0.0492946
# Early stopping, best iteration is:
# [14120]	training's l1: 0.00603627	valid_1's l1: 0.0483478
# Training on fold 5
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0196466	valid_1's l1: 0.0509805
# [10000]	training's l1: 0.00944318	valid_1's l1: 0.0482902
# [15000]	training's l1: 0.00552847	valid_1's l1: 0.0473122
# [20000]	training's l1: 0.00365718	valid_1's l1: 0.0468493
# Early stopping, best iteration is:
# [22589]	training's l1: 0.00306917	valid_1's l1: 0.0466936
# Training on fold 6
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0196017	valid_1's l1: 0.051501
# [10000]	training's l1: 0.00955225	valid_1's l1: 0.0487984
# Early stopping, best iteration is:
# [10768]	training's l1: 0.00870025	valid_1's l1: 0.048604
# Training on fold 7
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.019491	valid_1's l1: 0.0551842
# [10000]	training's l1: 0.00949965	valid_1's l1: 0.0523089
# Early stopping, best iteration is:
# [13946]	training's l1: 0.00618391	valid_1's l1: 0.0514326
# Training on fold 8
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.019542	valid_1's l1: 0.0531231
# [10000]	training's l1: 0.009462	valid_1's l1: 0.0503325
# [15000]	training's l1: 0.00552903	valid_1's l1: 0.0492121
# [20000]	training's l1: 0.00366236	valid_1's l1: 0.0486936
# [25000]	training's l1: 0.00265071	valid_1's l1: 0.0484159
# Early stopping, best iteration is:
# [27515]	training's l1: 0.00231179	valid_1's l1: 0.0483324
# Training on fold 9
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0198176	valid_1's l1: 0.0530773
# Early stopping, best iteration is:
# [7717]	training's l1: 0.0129364	valid_1's l1: 0.0511668
# Training on fold 10
# Training until validation scores don't improve for 50 rounds.
# [5000]	training's l1: 0.0195939	valid_1's l1: 0.0540386
# [10000]	training's l1: 0.00943156	valid_1's l1: 0.0511994
# [15000]	training's l1: 0.00551082	valid_1's l1: 0.0502013
# Early stopping, best iteration is:
# [18438]	training's l1: 0.00409962	valid_1's l1: 0.0498645
# ------------------------------
# Training has finished.
# Total training time is 0:03:00.043824
# ------------------------------
# this self.model`s rmse: 285
# RMSE :  285.16976687746455
# R^2 :  0.919034536043311

# %%
def plot_scatter(oof,train_y):
    print('RMSE : ', np.sqrt(mean_squared_error(oof,train_y)))
    print('R^2 : ', r2_score(oof,train_y))
    plt.figure()
    plt.scatter(oof,train_y, alpha=0.7)
    plt.title("$R^2 = {:<.5}$".format(r2_score(oof,train_y)))
    x = np.linspace(0, 2500000, 100)
    plt.plot(x, x, c="indianred")
    plt.xlabel('predict', size=20)
    plt.ylabel('correct', size=20)

# %%
log_lgboof2=log_lgboof*X_train['面積']
log_lgbpreds2=log_lgbpreds*X_test['面積']

# %%
plot_scatter(log_lgboof2, y_train)
# Out:
# RMSE :  14989.476719352991
# R^2 :  0.9557951350979206

# %%
plot_scatter(log_lgboof2, y_train)
# Out:
# RMSE :  15228.564564500552
# R^2 :  0.9548034004803847

# %%
rmse=int(np.sqrt(mean_squared_error(log_lgboof2, y_train)))

# %%
save_data(X_train,log_lgboof2, log_lgbpreds2,rmse=rmse,name='log_km_area_per_locmodified',save_dir='./stacking')
# Out:
#       id         target
# 0  31471  129936.020162
# 1  31472  118902.301466
# 2  31473   75069.319651
# 3  31474   60287.091161
# 4  31475   93790.899902
#    id         target
# 0   1   75219.869160
# 1   2   63149.740270
# 2   3  110335.035835
# 3   4  163378.430156
# 4   5   68851.000115

# %%
oof1=pd.read_csv('./stacking/oof_14989_log_km_area_per_locmodified.csv',header=None)
oof2=pd.read_csv('./stacking/oof_15040_log_km_wa_locmodified.csv',header=None)

# %%
plot_scatter(oof1[1],y_train)
# Out:
# RMSE :  14989.476719352991
# R^2 :  0.9557951350979206

# %%
plot_scatter((oof1[1]+oof2[1])/2,y_train)
# Out:
# RMSE :  14485.371750285089
# R^2 :  0.9583373056268507

# %%
pred1=pd.read_csv('./stacking/submit_14989_log_km_area_per_locmodified.csv',header=None)
pred2=pd.read_csv('./stacking/submit_15040_log_km_wa_locmodified.csv',header=None)

# %%
pred3=pred2.copy()

# %%
pred3[1]=(pred1[1]+pred2[1])/2

# %%
pred3.to_csv('./submit/1105_mean.csv',header=None,index=None)
